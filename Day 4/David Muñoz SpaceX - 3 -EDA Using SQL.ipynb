# %% [markdown]
# # Etapa 3: Análisis de datos utilizando SQL

# %% [markdown]
# ## Objetivos
#
# En esta práctica subiremos los datos a una base de datos SQL y realizaremos diferentes queries para obtener información sobre los datos

# %%
# !pip install sqlalchemy==1.4.16 --quiet
import pandas as pd
import numpy as np
# !pip install PyMySQL --quiet
import pymysql as pymsql
# !pip install mysql-connector --quiet
import mysql.connector
from sqlalchemy import create_engine
# !pip install sqlalchemy-utils --quiet
from sqlalchemy_utils import database_exists, create_database
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 44.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for sqlalchemy (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.16 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 971.7 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 29.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for mysql-connector (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 kB 1.9 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Tarea 1: Subir los datos a la base de datos:

# %% [markdown]
# Primero cargamos el archivo de datos `dataset_part_2.csv`.

# %%
df_path = "/content/drive/MyDrive/dataset_part_2.csv"
df = pd.read_csv(df_path)

# %%
#Rellena la siguiente variable con tu nombre y apellido (Todo junto y sin espacios).
nombreBD = 'davidmuñoz'
linkConexion = 'mysql+mysqlconnector://alumno:385bd4cf713a8a36@35.180.211.139/' + nombreBD
#Establecemos la conexión
engine = create_engine(linkConexion)

# %%
if not database_exists(engine.url):
    create_database(engine.url)

# %%
# Añadir el dataframe a sql SPACEXTBL usando la función to_sql().
df.to_sql('SPACEXTBL',engine)
# Out:
# -1

# %%
query = "select * from SPACEXTBL;"
df  = pd.read_sql(query,  engine )
df
# Out:
#     index  FlightNumber        Date BoosterVersion   PayloadMass  \
# 0       0             1  2010-06-04       Falcon 9   6123.547647
# 1       1             2  2012-05-22       Falcon 9    525.000000
# 2       2             3  2013-03-01       Falcon 9    677.000000
# 3       3             4  2013-09-29       Falcon 9    500.000000
# 4       4             5  2013-12-03       Falcon 9   3170.000000
# ..    ...           ...         ...            ...           ...
# 85     85            86  2020-09-03       Falcon 9  15600.000000
# 86     86            87  2020-10-06       Falcon 9  15600.000000
# 87     87            88  2020-10-18       Falcon 9  15600.000000
# 88     88            89  2020-10-24       Falcon 9  15600.000000
# 89     89            90  2020-11-05       Falcon 9   3681.000000
#
#                       Payload Orbit    LaunchSite LandingOutcome  Flights  \
# 0   Dragon Qualification Unit   LEO  CCSFS SLC 40      None None        1
# 1          COTS Demo Flight 2   LEO  CCSFS SLC 40      None None        1
# 2                       CRS-2   ISS  CCSFS SLC 40      None None        1
# 3                    CASSIOPE    PO   VAFB SLC 4E    False Ocean        1
# 4                       SES-8   GTO  CCSFS SLC 40      None None        1
# ..                        ...   ...           ...            ...      ...
# 85                Starlink-11  VLEO    KSC LC 39A      True ASDS        2
# 86                Starlink-12  VLEO    KSC LC 39A      True ASDS        3
# 87                Starlink-13  VLEO    KSC LC 39A      True ASDS        6
# 88                Starlink-14  VLEO  CCSFS SLC 40      True ASDS        3
# 89   GPS III SV04 (Sacagawea)   MEO  CCSFS SLC 40      True ASDS        1
#
#     GridFins  Reused  Legs                LandingPad  Block  \
# 0          0       0     0                      None    1.0
# 1          0       0     0                      None    1.0
# 2          0       0     0                      None    1.0
# 3          0       0     0                      None    1.0
# 4          0       0     0                      None    1.0
# ..       ...     ...   ...                       ...    ...
# 85         1       1     1  5e9e3032383ecb6bb234e7ca    5.0
# 86         1       1     1  5e9e3032383ecb6bb234e7ca    5.0
# 87         1       1     1  5e9e3032383ecb6bb234e7ca    5.0
# 88         1       1     1  5e9e3033383ecbb9e534e7cc    5.0
# 89         1       0     1  5e9e3032383ecb6bb234e7ca    5.0
#
#                     Customers  Mission_Outcome  ReusedCount Serial  \
# 0                      SpaceX                1            0  B0003
# 1                  NASA(COTS)                1            0  B0005
# 2                  NASA (CRS)                1            0  B0007
# 3                         MDA                1            0  B1003
# 4                         SES                1            0  B1004
# ..                        ...              ...          ...    ...
# 85                     SpaceX                1           12  B1060
# 86                     SpaceX                1           13  B1058
# 87                     SpaceX                1           12  B1051
# 88                     SpaceX                1           12  B1060
# 89  United States Space Force                1            8  B1062
#
#      Longitude   Latitude  Class
# 0   -80.577366  28.561857      0
# 1   -80.577366  28.561857      0
# 2   -80.577366  28.561857      0
# 3  -120.610829  34.632093      0
# 4   -80.577366  28.561857      0
# ..         ...        ...    ...
# 85  -80.603956  28.608058      1
# 86  -80.603956  28.608058      1
# 87  -80.603956  28.608058      1
# 88  -80.577366  28.561857      1
# 89  -80.577366  28.561857      1
#
# [90 rows x 22 columns]

# %% [markdown]
# ## Tarea 2: Queries con SQL

# %% [markdown]
# ### Ejercicio 1
#
# ##### Muestra las diferentes plataformas de lanzamiento:

# %%
#Rellena la variable query con tu consulta
query = """  SELECT DISTINCT(LaunchSite)
             FROM SPACEXTBL  """
df  = pd.read_sql(query, con = engine )
df
# Out:
#      LaunchSite
# 0  CCSFS SLC 40
# 1   VAFB SLC 4E
# 2    KSC LC 39A

# %% [markdown]
# ### Ejercicio 2
#
# ##### Muestra 5 lanzamientos cuya plataforma empiece por 'CCS'

# %%
from numpy.core.multiarray import where
#Rellena la variable query con tu consulta
#Rellena la variable query con tu consulta
query = """  SELECT *
             FROM SPACEXTBL
             where LaunchSite LIKE 'CCS%'
             LIMIT 5 """
df  = pd.read_sql(query, con = engine )
df
# Out:
#    index  FlightNumber        Date BoosterVersion  PayloadMass  \
# 0      0             1  2010-06-04       Falcon 9  6123.547647
# 1      1             2  2012-05-22       Falcon 9   525.000000
# 2      2             3  2013-03-01       Falcon 9   677.000000
# 3      4             5  2013-12-03       Falcon 9  3170.000000
# 4      5             6  2014-01-06       Falcon 9  3325.000000
#
#                      Payload Orbit    LaunchSite LandingOutcome  Flights  \
# 0  Dragon Qualification Unit   LEO  CCSFS SLC 40      None None        1
# 1         COTS Demo Flight 2   LEO  CCSFS SLC 40      None None        1
# 2                      CRS-2   ISS  CCSFS SLC 40      None None        1
# 3                      SES-8   GTO  CCSFS SLC 40      None None        1
# 4                  Thaicom 6   GTO  CCSFS SLC 40      None None        1
#
#    GridFins  Reused  Legs LandingPad  Block   Customers  Mission_Outcome  \
# 0         0       0     0       None    1.0      SpaceX                1
# 1         0       0     0       None    1.0  NASA(COTS)                1
# 2         0       0     0       None    1.0  NASA (CRS)                1
# 3         0       0     0       None    1.0         SES                1
# 4         0       0     0       None    1.0     Thaicom                1
#
#    ReusedCount Serial  Longitude   Latitude  Class
# 0            0  B0003 -80.577366  28.561857      0
# 1            0  B0005 -80.577366  28.561857      0
# 2            0  B0007 -80.577366  28.561857      0
# 3            0  B1004 -80.577366  28.561857      0
# 4            0  B1005 -80.577366  28.561857      0

# %% [markdown]
# ### Ejercicio 3
#
# ##### Mustra el la masa total transportada por los lanzamientos realizados donde el cliente es NASA (CRS)

# %%
#Rellena la variable query con tu consulta
query = """  SELECT *
             FROM SPACEXTBL
             where Customers = 'NASA (CRS)' """
df  = pd.read_sql(query, con = engine )
df
# Out:
#     index  FlightNumber        Date BoosterVersion  PayloadMass Payload Orbit  \
# 0       2             3  2013-03-01       Falcon 9        677.0   CRS-2   ISS
# 1       6             7  2014-04-18       Falcon 9       2296.0   CRS-3   ISS
# 2      10            11  2014-09-21       Falcon 9       2216.0   CRS-4   ISS
# 3      11            12  2015-01-10       Falcon 9       2395.0   CRS-5   ISS
# 4      13            14  2015-04-14       Falcon 9       1898.0   CRS-6   ISS
# 5      15            16  2015-06-28       Falcon 9       2477.0   CRS-7   ISS
# 6      19            20  2016-04-08       Falcon 9       3136.0   CRS-8   ISS
# 7      22            23  2016-07-18       Falcon 9       2257.0   CRS-9   ISS
# 8      26            27  2017-02-19       Falcon 9       2490.0  CRS-10   ISS
# 9      31            32  2017-06-03       Falcon 9       2708.0  CRS-11   ISS
# 10     35            36  2017-08-14       Falcon 9       2910.0  CRS-12   ISS
# 11     41            42  2017-12-15       Falcon 9       2205.0  CRS-13   ISS
# 12     47            48  2018-04-02       Falcon 9       2760.0  CRS-14   ISS
# 13     51            52  2018-06-29       Falcon 9       2410.0  CRS-15   ISS
# 14     59            60  2018-12-05       Falcon 9       2573.0  CRS-16   ISS
# 15     63            64  2019-05-04       Falcon 9       2482.0  CRS-17   ISS
# 16     66            67  2019-07-25       Falcon 9       2227.7  CRS-18   ISS
# 17     69            70  2019-12-05       Falcon 9       5000.0  CRS-19   ISS
# 18     75            76  2020-03-07       Falcon 9       1977.0  CRS-20   ISS
#
#       LaunchSite LandingOutcome  Flights  GridFins  Reused  Legs  \
# 0   CCSFS SLC 40      None None        1         0       0     0
# 1   CCSFS SLC 40     True Ocean        1         0       0     1
# 2   CCSFS SLC 40    False Ocean        1         0       0     0
# 3   CCSFS SLC 40     False ASDS        1         1       0     1
# 4   CCSFS SLC 40     False ASDS        1         1       0     1
# 5   CCSFS SLC 40      None ASDS        1         1       0     1
# 6   CCSFS SLC 40      True ASDS        1         1       0     1
# 7   CCSFS SLC 40      True RTLS        1         1       0     1
# 8     KSC LC 39A      True RTLS        1         1       0     1
# 9     KSC LC 39A      True RTLS        1         1       0     1
# 10    KSC LC 39A      True RTLS        1         1       0     1
# 11  CCSFS SLC 40      True RTLS        2         1       1     1
# 12  CCSFS SLC 40      None None        2         1       1     1
# 13  CCSFS SLC 40      None None        2         0       1     0
# 14  CCSFS SLC 40     False RTLS        1         1       0     1
# 15  CCSFS SLC 40      True ASDS        1         1       0     1
# 16  CCSFS SLC 40      True RTLS        2         1       1     1
# 17  CCSFS SLC 40      True ASDS        1         1       0     1
# 18  CCSFS SLC 40      True RTLS        2         1       1     1
#
#                   LandingPad  Block   Customers  Mission_Outcome  ReusedCount  \
# 0                       None    1.0  NASA (CRS)                1            0
# 1                       None    1.0  NASA (CRS)                1            0
# 2                       None    1.0  NASA (CRS)                1            0
# 3   5e9e3032383ecb761634e7cb    1.0  NASA (CRS)                1            0
# 4   5e9e3032383ecb761634e7cb    1.0  NASA (CRS)                1            0
# 5   5e9e3032383ecb6bb234e7ca    1.0  NASA (CRS)                0            0
# 6   5e9e3032383ecb6bb234e7ca    2.0  NASA (CRS)                1            1
# 7   5e9e3032383ecb267a34e7c7    2.0  NASA (CRS)                1            1
# 8   5e9e3032383ecb267a34e7c7    3.0  NASA (CRS)                1            1
# 9   5e9e3032383ecb267a34e7c7    3.0  NASA (CRS)                1            1
# 10  5e9e3032383ecb267a34e7c7    4.0  NASA (CRS)                1            1
# 11  5e9e3032383ecb267a34e7c7    3.0  NASA (CRS)                1            1
# 12                      None    4.0  NASA (CRS)                1            1
# 13                      None    4.0  NASA (CRS)                1            1
# 14  5e9e3032383ecb267a34e7c7    5.0  NASA (CRS)                1            0
# 15  5e9e3032383ecb6bb234e7ca    5.0  NASA (CRS)                1            3
# 16  5e9e3032383ecb267a34e7c7    5.0  NASA (CRS)                1            3
# 17  5e9e3032383ecb6bb234e7ca    5.0  NASA (CRS)                1            5
# 18  5e9e3032383ecb267a34e7c7    5.0  NASA (CRS)                1            5
#
#    Serial  Longitude   Latitude  Class
# 0   B0007 -80.577366  28.561857      0
# 1   B1006 -80.577366  28.561857      1
# 2   B1010 -80.577366  28.561857      0
# 3   B1012 -80.577366  28.561857      0
# 4   B1015 -80.577366  28.561857      0
# 5   B1018 -80.577366  28.561857      0
# 6   B1021 -80.577366  28.561857      1
# 7   B1025 -80.577366  28.561857      1
# 8   B1031 -80.603956  28.608058      1
# 9   B1035 -80.603956  28.608058      1
# 10  B1039 -80.603956  28.608058      1
# 11  B1035 -80.577366  28.561857      1
# 12  B1039 -80.577366  28.561857      0
# 13  B1045 -80.577366  28.561857      0
# 14  B1050 -80.577366  28.561857      0
# 15  B1056 -80.577366  28.561857      1
# 16  B1056 -80.577366  28.561857      1
# 17  B1059 -80.577366  28.561857      1
# 18  B1059 -80.577366  28.561857      1

# %% [markdown]
# ### Ejercicio 4
#
# ##### Muestra la masa media tranportada por lanzamientos con serie que comienza por B1

# %%
query = """  SELECT AVG (PayloadMass)
             FROM SPACEXTBL
             where Serial LIKE 'B1%' """
df  = pd.read_sql(query, con = engine )
df
# Out:
#    AVG (PayloadMass)
# 0        6250.502765

# %% [markdown]
# ### Ejercicio 5
#
# ##### Muestra la fecha donde se realizo el primer aterrizaje exitoso sobre terreno (TRUE RTLS)
#
# *Pista:Utiliza la función min*

# %%
query = """  SELECT LandingOutcome, MIN(Date)
             FROM SPACEXTBL
             where LandingOutcome = 'True RTLS' """
df  = pd.read_sql(query, con = engine )
df
# Out:
#   LandingOutcome   MIN(Date)
# 0      True RTLS  2015-12-22

# %% [markdown]
# ### Ejercicio 6
#
# ##### Muestra las series de los cohetes que aterrizaron sobre portaviones (TRUE ASDS) con una masa entre 4000 y 6000

# %%
query = """  SELECT Serial, DATE
             FROM SPACEXTBL
             where 'LandingOutcome' LIKE 'TRUE ASDS' AND 'PayloadMass' BETWEEN 4000 AND 6000 """
df  = pd.read_sql(query, con = engine )
df
# Out:
# Empty DataFrame
# Columns: [Serial, DATE]
# Index: []

# %% [markdown]
# ### Ejercicio 7
#
# ##### Muestra el numero de lanzamientos que completaron su mision correctamente y aquellos que fallaron

# %%
query = """  SELECT Mission_Outcome
             FROM SPACEXTBL
             where Mission_Outcome = '0,1' """
df  = pd.read_sql(query, con = engine )
df
# Out:
#    Mission_Outcome
# 0                0
# 1                0

# %% [markdown]
# ### Ejercicio 8
#
# ##### Muestra las series de los cohetes que transportaron la masa máxima

# %%
query = """  SELECT PayloadMass, Serial
             FROM SPACEXTBL
             where PayloadMass """
df  = pd.read_sql(query, con = engine )
df
# Out:
#      PayloadMass Serial
# 0    6123.547647  B0003
# 1     525.000000  B0005
# 2     677.000000  B0007
# 3     500.000000  B1003
# 4    3170.000000  B1004
# ..           ...    ...
# 85  15600.000000  B1060
# 86  15600.000000  B1058
# 87  15600.000000  B1051
# 88  15600.000000  B1060
# 89   3681.000000  B1062
#
# [90 rows x 2 columns]

# %% [markdown]
# ### Ejercicio 9
#
# ##### Muestra los el resultados del aterrizaje, la serie del cohete y las plataforma de lanzamiento de aquellos lanzamientos fallidos o no intentados en el año 2015

# %%
query = """  SELECT PayloadMass, Serial
             FROM SPACEXTBL
             where PayloadMass """
df  = pd.read_sql(query, con = engine )
df

# %% [markdown]
# ### Ejercicio 10
#
# ##### Muestra los resultados y la frecuencia de estos resultados entre 2010-06-04 y 2017-03-20 ordenados en orden descendiente según la frecuencia
